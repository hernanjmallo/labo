# %%
#Feature Engineering
#creo nuevas variables dentro del mismo mes
#Condimentar a gusto con nuevas variables

#limpio la memoria
rm( list=ls() )
gc()

require("data.table")

#Establezco el Working Directory
setwd("~/")


EnriquecerDataset <- function( dataset , arch_destino )
{
  columnas_originales <-  copy(colnames( dataset ))


dataset[ , mpasivos_margen_adj       := ifelse( foto_mes == '202101' ,   mpasivos_margen*1.158,
                                        ifelse( foto_mes == '202102' ,   mpasivos_margen*1.122,
                                        ifelse( foto_mes == '202103' ,   mpasivos_margen*1.074,
                                        ifelse( foto_mes == '202104' ,   mpasivos_margen*1.033,
                                        ifelse( foto_mes == '202105' ,   mpasivos_margen, mpasivos_margen )))))]

dataset[ , mpayroll_adj              := ifelse( foto_mes == '202101' ,   mpayroll*1.158,
                                        ifelse( foto_mes == '202102' ,   mpayroll*1.122,
                                        ifelse( foto_mes == '202103' ,   mpayroll*1.074,
                                        ifelse( foto_mes == '202104' ,   mpayroll*1.033,
                                        ifelse( foto_mes == '202105' ,   mpayroll, mpayroll )))))]

dataset[ , mcuentas_saldo_adj        := ifelse( foto_mes == '202101' ,   mcuentas_saldo*1.158,
                                        ifelse( foto_mes == '202102' ,   mcuentas_saldo*1.122,
                                        ifelse( foto_mes == '202103' ,   mcuentas_saldo*1.074,
                                        ifelse( foto_mes == '202104' ,   mcuentas_saldo*1.033,
                                        ifelse( foto_mes == '202105' ,   mcuentas_saldo, mcuentas_saldo )))))]
    
dataset[ , mautoservicio_adj         := ifelse( foto_mes == '202101' ,   mautoservicio*1.158,
                                        ifelse( foto_mes == '202102' ,   mautoservicio*1.122,
                                        ifelse( foto_mes == '202103' ,   mautoservicio*1.074,
                                        ifelse( foto_mes == '202104' ,   mautoservicio*1.033,
                                        ifelse( foto_mes == '202105' ,   mautoservicio, mautoservicio )))))]

dataset[ , mprestamos_personales_adj := ifelse( foto_mes == '202101' ,   mprestamos_personales*1.158,
                                        ifelse( foto_mes == '202102' ,   mprestamos_personales*1.122,
                                        ifelse( foto_mes == '202103' ,   mprestamos_personales*1.074,
                                        ifelse( foto_mes == '202104' ,   mprestamos_personales*1.033,
                                        ifelse( foto_mes == '202105' ,   mprestamos_personales, mprestamos_personales )))))]

dataset[ , mrentabilidad_annual_adj  := ifelse( foto_mes == '202101' ,   mrentabilidad_annual*1.158,
                                        ifelse( foto_mes == '202102' ,   mrentabilidad_annual*1.122,
                                        ifelse( foto_mes == '202103' ,   mrentabilidad_annual*1.074,
                                        ifelse( foto_mes == '202104' ,   mrentabilidad_annual*1.033,
                                        ifelse( foto_mes == '202105' ,   mrentabilidad_annual, mrentabilidad_annual )))))]

dataset[ , mtarjeta_visa_consumo_adj       := ifelse( foto_mes == '202101' ,   mtarjeta_visa_consumo*1.158,
                                        ifelse( foto_mes == '202102' ,   mtarjeta_visa_consumo*1.122,
                                        ifelse( foto_mes == '202103' ,   mtarjeta_visa_consumo*1.074,
                                        ifelse( foto_mes == '202104' ,   mtarjeta_visa_consumo*1.033,
                                        ifelse( foto_mes == '202105' ,   mtarjeta_visa_consumo, mtarjeta_visa_consumo )))))]

dataset[ , mcaja_ahorro_adj       := ifelse( foto_mes == '202101' ,   mcaja_ahorro*1.158,
                                        ifelse( foto_mes == '202102' ,   mcaja_ahorro*1.122,
                                        ifelse( foto_mes == '202103' ,   mcaja_ahorro*1.074,
                                        ifelse( foto_mes == '202104' ,   mcaja_ahorro*1.033,
                                        ifelse( foto_mes == '202105' ,   mcaja_ahorro, mcaja_ahorro )))))]

dataset[ , mcomisiones_mantenimiento_adj       := ifelse( foto_mes == '202101' ,   mcomisiones_mantenimiento*1.158,
                                        ifelse( foto_mes == '202102' ,   mcomisiones_mantenimiento*1.122,
                                        ifelse( foto_mes == '202103' ,   mcomisiones_mantenimiento*1.074,
                                        ifelse( foto_mes == '202104' ,   mcomisiones_mantenimiento*1.033,
                                        ifelse( foto_mes == '202105' ,   mcomisiones_mantenimiento, mcomisiones_mantenimiento )))))]
    
dataset[ , mcuenta_corriente_adj       := ifelse( foto_mes == '202101' ,   mcuenta_corriente*1.158,
                                        ifelse( foto_mes == '202102' ,   mcuenta_corriente*1.122,
                                        ifelse( foto_mes == '202103' ,   mcuenta_corriente*1.074,
                                        ifelse( foto_mes == '202104' ,   mcuenta_corriente*1.033,
                                        ifelse( foto_mes == '202105' ,   mcuenta_corriente, mcuenta_corriente )))))]

dataset[ , mactivos_margen_adj       := ifelse( foto_mes == '202101' ,   mactivos_margen*1.158,
                                        ifelse( foto_mes == '202102' ,   mactivos_margen*1.122,
                                        ifelse( foto_mes == '202103' ,   mactivos_margen*1.074,
                                        ifelse( foto_mes == '202104' ,   mactivos_margen*1.033,
                                        ifelse( foto_mes == '202105' ,   mactivos_margen, mactivos_margen )))))]

dataset[ , mrentabilidad_adj       := ifelse( foto_mes == '202101' ,   mrentabilidad*1.158,
                                        ifelse( foto_mes == '202102' ,   mrentabilidad*1.122,
                                        ifelse( foto_mes == '202103' ,   mrentabilidad*1.074,
                                        ifelse( foto_mes == '202104' ,   mrentabilidad*1.033,
                                        ifelse( foto_mes == '202105' ,   mrentabilidad, mrentabilidad )))))]

dataset[ , Visa_msaldototal_adj       := ifelse( foto_mes == '202101' ,   Visa_msaldototal*1.158,
                                        ifelse( foto_mes == '202102' ,   Visa_msaldototal*1.122,
                                        ifelse( foto_mes == '202103' ,   Visa_msaldototal*1.074,
                                        ifelse( foto_mes == '202104' ,   Visa_msaldototal*1.033,
                                        ifelse( foto_mes == '202105' ,   Visa_msaldototal, Visa_msaldototal )))))]
    
dataset[ , Visa_mpagospesos_adj       := ifelse( foto_mes == '202101' ,   Visa_mpagospesos*1.158,
                                        ifelse( foto_mes == '202102' ,   Visa_mpagospesos*1.122,
                                        ifelse( foto_mes == '202103' ,   Visa_mpagospesos*1.074,
                                        ifelse( foto_mes == '202104' ,   Visa_mpagospesos*1.033,
                                        ifelse( foto_mes == '202105' ,   Visa_mpagospesos, Visa_mpagospesos )))))]

dataset[ , mcomisiones_adj            := ifelse( foto_mes == '202101' ,   mcomisiones*1.158,
                                        ifelse( foto_mes == '202102' ,   mcomisiones*1.122,
                                        ifelse( foto_mes == '202103' ,   mcomisiones*1.074,
                                        ifelse( foto_mes == '202104' ,   mcomisiones*1.033,
                                        ifelse( foto_mes == '202105' ,   mcomisiones, mcomisiones )))))]

dataset[ , Visa_mconsumospesos_adj   := ifelse( foto_mes == '202101' ,   Visa_mconsumospesos*1.158,
                                        ifelse( foto_mes == '202102' ,   Visa_mconsumospesos*1.122,
                                        ifelse( foto_mes == '202103' ,   Visa_mconsumospesos*1.074,
                                        ifelse( foto_mes == '202104' ,   Visa_mconsumospesos*1.033,
                                        ifelse( foto_mes == '202105' ,   Visa_mconsumospesos, Visa_mconsumospesos )))))]

dataset[ , Visa_mfinanciacion_limite_adj   := ifelse( foto_mes == '202101' ,   Visa_mfinanciacion_limite*1.158,
                                        ifelse( foto_mes == '202102' ,   Visa_mfinanciacion_limite*1.122,
                                        ifelse( foto_mes == '202103' ,   Visa_mfinanciacion_limite*1.074,
                                        ifelse( foto_mes == '202104' ,   Visa_mfinanciacion_limite*1.033,
                                        ifelse( foto_mes == '202105' ,   Visa_mfinanciacion_limite, Visa_mfinanciacion_limite )))))]

dataset[ , mtransferencias_recibidas_adj   := ifelse( foto_mes == '202101' ,   mtransferencias_recibidas*1.158,
                                        ifelse( foto_mes == '202102' ,   mtransferencias_recibidas*1.122,
                                        ifelse( foto_mes == '202103' ,   mtransferencias_recibidas*1.074,
                                        ifelse( foto_mes == '202104' ,   mtransferencias_recibidas*1.033,
                                        ifelse( foto_mes == '202105' ,   mtransferencias_recibidas, mtransferencias_recibidas )))))]

dataset[ , Master_mfinanciacion_limite_adj   := ifelse( foto_mes == '202101' ,   Master_mfinanciacion_limite*1.158,
                                        ifelse( foto_mes == '202102' ,   Master_mfinanciacion_limite*1.122,
                                        ifelse( foto_mes == '202103' ,   Master_mfinanciacion_limite*1.074,
                                        ifelse( foto_mes == '202104' ,   Master_mfinanciacion_limite*1.033,
                                        ifelse( foto_mes == '202105' ,   Master_mfinanciacion_limite, Master_mfinanciacion_limite )))))]

dataset[ , mcomisiones_otras_adj     := ifelse( foto_mes == '202101' ,   mcomisiones_otras*1.158,
                                        ifelse( foto_mes == '202102' ,   mcomisiones_otras*1.122,
                                        ifelse( foto_mes == '202103' ,   mcomisiones_otras*1.074,
                                        ifelse( foto_mes == '202104' ,   mcomisiones_otras*1.033,
                                        ifelse( foto_mes == '202105' ,   mcomisiones_otras, mcomisiones_otras )))))]

dataset[ , mcaja_ahorro_dolares_adj  := ifelse( foto_mes == '202101' ,   mcaja_ahorro_dolares*1.158,
                                        ifelse( foto_mes == '202102' ,   mcaja_ahorro_dolares*1.122,
                                        ifelse( foto_mes == '202103' ,   mcaja_ahorro_dolares*1.074,
                                        ifelse( foto_mes == '202104' ,   mcaja_ahorro_dolares*1.033,
                                        ifelse( foto_mes == '202105' ,   mcaja_ahorro_dolares, mcaja_ahorro_dolares )))))]

dataset[ ,mttarjeta_visa_debitos_automaticos_adj  := ifelse( foto_mes == '202101' ,   mttarjeta_visa_debitos_automaticos*1.158,
                                        ifelse( foto_mes == '202102' ,   mttarjeta_visa_debitos_automaticos*1.122,
                                        ifelse( foto_mes == '202103' ,   mttarjeta_visa_debitos_automaticos*1.074,
                                        ifelse( foto_mes == '202104' ,   mttarjeta_visa_debitos_automaticos*1.033,
                                        ifelse( foto_mes == '202105' ,   mttarjeta_visa_debitos_automaticos, mttarjeta_visa_debitos_automaticos )))))]

dataset[ , mtransferencias_emitidas_adj  := ifelse( foto_mes == '202101' ,   mtransferencias_emitidas*1.158,
                                        ifelse( foto_mes == '202102' ,   mtransferencias_emitidas*1.122,
                                        ifelse( foto_mes == '202103' ,   mtransferencias_emitidas*1.074,
                                        ifelse( foto_mes == '202104' ,   mtransferencias_emitidas*1.033,
                                        ifelse( foto_mes == '202105' ,   mtransferencias_emitidas, mtransferencias_emitidas )))))]

dataset[ , Visa_msaldopesos_adj  := ifelse( foto_mes == '202101' ,   Visa_msaldopesos*1.158,
                                        ifelse( foto_mes == '202102' ,   Visa_msaldopesos*1.122,
                                        ifelse( foto_mes == '202103' ,   Visa_msaldopesos*1.074,
                                        ifelse( foto_mes == '202104' ,   Visa_msaldopesos*1.033,
                                        ifelse( foto_mes == '202105' ,   Visa_msaldopesos, Visa_msaldopesos )))))]
    
    #dataset[, ctrx_quarter_rank := frank(ctrx_quarter),  by = list(foto_mes)]
    #dataset[, mpasivos_margen_rank := frank(mpasivos_margen),  by = list(foto_mes)]
    #dataset[, ctrx_quarter_rank := frank(ctrx_quarter),  by = list(foto_mes)]
    #dataset[, cpayroll_trx_rank := frank(cpayroll_trx),  by = list(foto_mes)]
    #dataset[, ctarjeta_visa_transacciones_rank := frank(ctarjeta_visa_transacciones),  by = list(foto_mes)]
    #dataset[, mpayroll_rank := frank(mpayroll),  by = list(foto_mes)]
    #dataset[, mcuentas_saldo_rank := frank(mcuentas_saldo),  by = list(foto_mes)]
    #dataset[, mautoservicio_rank := frank(mautoservicio),  by = list(foto_mes)]
    #dataset[, mprestamos_personales_rank := frank(mprestamos_personales),  by = list(foto_mes)]
    #dataset[, mrentabilidad_annual_rank := frank(mrentabilidad_annual),  by = list(foto_mes)]
    #dataset[, mtarjeta_visa_consumo_rank := frank(mtarjeta_visa_consumo),  by = list(foto_mes)]
    #dataset[, mcaja_ahorro_rank := frank(mcaja_ahorro),  by = list(foto_mes)]
    #dataset[, mcomisiones_mantenimiento_rank := frank(mcomisiones_mantenimiento),  by = list(foto_mes)]
    #dataset[, mcuenta_corriente_rank := frank(mcuenta_corriente),  by = list(foto_mes)]
    #dataset[, ccomisiones_mantenimiento_rank := frank(ccomisiones_mantenimiento),  by = list(foto_mes)]
    #dataset[, Visa_mpagominimo_rank := frank(Visa_mpagominimo),  by = list(foto_mes)]
    #dataset[, mactivos_margen_rank := frank(mactivos_margen),  by = list(foto_mes)]
    #dataset[, cproductos_rank := frank(cproductos),  by = list(foto_mes)]
    #dataset[, mrentabilidad_rank := frank(mrentabilidad),  by = list(foto_mes)]
    #dataset[, Visa_Fvencimiento_rank := frank(Visa_Fvencimiento),  by = list(foto_mes)]
    #dataset[, Visa_msaldopesos_rank := frank(Visa_msaldopesos),  by = list(foto_mes)]
    #dataset[, Master_fechaalta_rank := frank(Master_fechaalta),  by = list(foto_mes)]
    #dataset[, cliente_edad_rank := frank(cliente_edad),  by = list(foto_mes)]
    #dataset[, Master_Fvencimiento_rank := frank(Master_Fvencimiento),  by = list(foto_mes)]
    #dataset[, ctarjeta_debito_transacciones_rank := frank(ctarjeta_debito_transacciones),  by = list(foto_mes)]
    #dataset[, Visa_fechaalta_rank := frank(Visa_fechaalta),  by = list(foto_mes)]
    #dataset[, Visa_msaldototal_rank := frank(Visa_msaldototal),  by = list(foto_mes)]
    #dataset[, ccomisiones_otras_rank := frank(ccomisiones_otras),  by = list(foto_mes)]
    #dataset[, chomebanking_transacciones_rank := frank(chomebanking_transacciones),  by = list(foto_mes)]
    #dataset[, Visa_mpagospesos_rank := frank(Visa_mpagospesos),  by = list(foto_mes)]
    #dataset[, cliente_antiguedad_rank := frank(cliente_antiguedad),  by = list(foto_mes)]
    #dataset[, mcomisiones_rank := frank(mcomisiones),  by = list(foto_mes)]

    #dataset[, ctrx_quarter_rank  :=as.vector(scale(ctrx_quarter)),by=foto_mes]
    #dataset[, mpasivos_margen_rank  :=as.vector(scale(mpasivos_margen)),by=foto_mes]
    #dataset[, ctrx_quarter_rank  :=as.vector(scale(ctrx_quarter)),by=foto_mes]
    #dataset[, cpayroll_trx_rank  :=as.vector(scale(cpayroll_trx)),by=foto_mes]
    #dataset[, ctarjeta_visa_transacciones_rank  :=as.vector(scale(ctarjeta_visa_transacciones)),by=foto_mes]
    #dataset[, mpayroll_rank  :=as.vector(scale(mpayroll)),by=foto_mes]
    #dataset[, mcuentas_saldo_rank  :=as.vector(scale(mcuentas_saldo)),by=foto_mes]
    #dataset[, mautoservicio_rank  :=as.vector(scale(mautoservicio)),by=foto_mes]
    #dataset[, mprestamos_personales_rank  :=as.vector(scale(mprestamos_personales)),by=foto_mes]
    #dataset[, mrentabilidad_annual_rank  :=as.vector(scale(mrentabilidad_annual)),by=foto_mes]
    #dataset[, mtarjeta_visa_consumo_rank  :=as.vector(scale(mtarjeta_visa_consumo)),by=foto_mes]
    #dataset[, mcaja_ahorro_rank  :=as.vector(scale(mcaja_ahorro)),by=foto_mes]
    #dataset[, mcomisiones_mantenimiento_rank  :=as.vector(scale(mcomisiones_mantenimiento)),by=foto_mes]
    #dataset[, mcuenta_corriente_rank  :=as.vector(scale(mcuenta_corriente)),by=foto_mes]
    #dataset[, ccomisiones_mantenimiento_rank  :=as.vector(scale(ccomisiones_mantenimiento)),by=foto_mes]
    #dataset[, Visa_mpagominimo_rank  :=as.vector(scale(Visa_mpagominimo)),by=foto_mes]
    #dataset[, mactivos_margen_rank  :=as.vector(scale(mactivos_margen)),by=foto_mes]
    #dataset[, cproductos_rank  :=as.vector(scale(cproductos)),by=foto_mes]
    #dataset[, mrentabilidad_rank  :=as.vector(scale(mrentabilidad)),by=foto_mes]
    #dataset[, Visa_Fvencimiento_rank  :=as.vector(scale(Visa_Fvencimiento)),by=foto_mes]
    #dataset[, Visa_msaldopesos_rank  :=as.vector(scale(Visa_msaldopesos)),by=foto_mes]
    #dataset[, Master_fechaalta_rank  :=as.vector(scale(Master_fechaalta)),by=foto_mes]
    #dataset[, cliente_edad_rank  :=as.vector(scale(cliente_edad)),by=foto_mes]
    #dataset[, Master_Fvencimiento_rank  :=as.vector(scale(Master_Fvencimiento)),by=foto_mes]
    #dataset[, ctarjeta_debito_transacciones_rank  :=as.vector(scale(ctarjeta_debito_transacciones)),by=foto_mes]
    #dataset[, Visa_fechaalta_rank  :=as.vector(scale(Visa_fechaalta)),by=foto_mes]
    #dataset[, Visa_msaldototal_rank  :=as.vector(scale(Visa_msaldototal)),by=foto_mes]
    #dataset[, ccomisiones_otras_rank  :=as.vector(scale(ccomisiones_otras)),by=foto_mes]
    #dataset[, chomebanking_transacciones_rank  :=as.vector(scale(chomebanking_transacciones)),by=foto_mes]
    #dataset[, Visa_mpagospesos_rank  :=as.vector(scale(Visa_mpagospesos)),by=foto_mes]
    #dataset[, cliente_antiguedad_rank  :=as.vector(scale(cliente_antiguedad)),by=foto_mes]
    #dataset[, mcomisiones_rank  :=as.vector(scale(mcomisiones)),by=foto_mes]

    
  columnas_extendidas <-  copy( setdiff(  colnames(dataset), columnas_originales ) )
  
   #delete original attributes without inflation adjustment
  dataset[, c('mpasivos_margen','mpayroll','mcuentas_saldo','mautoservicio','mprestamos_personales','mrentabilidad_annual','mtarjeta_visa_consumo','mcaja_ahorro',
              'mcomisiones_mantenimiento','mcuenta_corriente','mactivos_margen','mrentabilidad','Visa_msaldototal','Visa_mpagospesos','mcomisiones',
              'Visa_mconsumospesos','Visa_mfinanciacion_limite','mtransferencias_recibidas','Master_mfinanciacion_limite','mcomisiones_otras','mcaja_ahorro_dolares',
              'mttarjeta_visa_debitos_automaticos',	'mtransferencias_emitidas','Visa_msaldopesos'):=NULL]
 
 
   
  #grabo con nombre extendido
  fwrite( dataset,
          file=arch_destino,
          sep= "," )
}
#------------------------------------------------------------------------------

#kcarpeta_datasets    <- "../input/laboratorio-de-implementacion-i-2021/"   #KAGGLE
kcarpeta_datasets    <- "./buckets/b1/datasets/"                          #VM o Ubuntu

#Archivo con datos etiquetados para entrenamiento
karchivo_entrada      <-  paste0(kcarpeta_datasets, "competencia2_2022.csv.gz")
karchivo_salida      <-  paste0(kcarpeta_datasets, "competencia2_2022_FE.csv.gz")



#lectura rapida del dataset  usando fread  de la libreria  data.table
dataset1  <- fread(karchivo_entrada)

EnriquecerDataset( dataset1, karchivo_salida )



quit( save="no")
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  729423 39.0   1349487    72.1   1349487   72.1
# Vcells 1407238 10.8 755119245  5761.2 943899056 7201.4
