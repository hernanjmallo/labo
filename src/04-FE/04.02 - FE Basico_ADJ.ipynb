# %%
#Feature Engineering
#creo nuevas variables dentro del mismo mes
#Condimentar a gusto con nuevas variables

#limpio la memoria
rm( list=ls() )
gc()

require("data.table")

#Establezco el Working Directory
setwd("~/")

EnriquecerDataset <- function( dataset , arch_destino )
{
  columnas_originales <-  copy(colnames( dataset ))

dataset[ , mpasivos_margen_adj          := ifelse( foto_mes == '202010' ,   mpasivos_margen*1.271,
                                           ifelse( foto_mes == '202011' ,   mpasivos_margen*1.239,
                                           ifelse( foto_mes == '202012' ,   mpasivos_margen*1.199,
                                           ifelse( foto_mes == '202101' ,   mpasivos_margen*1.158,
                                           ifelse( foto_mes == '202102' ,   mpasivos_margen*1.122,
                                           ifelse( foto_mes == '202103' ,   mpasivos_margen*1.074,
                                           ifelse( foto_mes == '202104' ,   mpasivos_margen*1.033,
                                           ifelse( foto_mes == '202105' ,   mpasivos_margen, mpasivos_margen))))))))]

dataset[ , mpayroll_adj                 := ifelse( foto_mes == '202010' ,   mpayroll*1.271,
                                           ifelse( foto_mes == '202011' ,   mpayroll*1.239,
                                           ifelse( foto_mes == '202012' ,   mpayroll*1.199,
                                           ifelse( foto_mes == '202101' ,   mpayroll*1.158,
                                           ifelse( foto_mes == '202102' ,   mpayroll*1.122,
                                           ifelse( foto_mes == '202103' ,   mpayroll*1.074,
                                           ifelse( foto_mes == '202104' ,   mpayroll*1.033,
                                           ifelse( foto_mes == '202105' ,   mpayroll, mpayroll))))))))]

dataset[ , mcuentas_saldo_adj           := ifelse( foto_mes == '202010' ,   mcuentas_saldo*1.271,
                                           ifelse( foto_mes == '202011' ,   mcuentas_saldo*1.239,
                                           ifelse( foto_mes == '202012' ,   mcuentas_saldo*1.199,
                                           ifelse( foto_mes == '202101' ,   mcuentas_saldo*1.158,
                                           ifelse( foto_mes == '202102' ,   mcuentas_saldo*1.122,
                                           ifelse( foto_mes == '202103' ,   mcuentas_saldo*1.074,
                                           ifelse( foto_mes == '202104' ,   mcuentas_saldo*1.033,
                                           ifelse( foto_mes == '202105' ,   mcuentas_saldo, mcuentas_saldo))))))))]

dataset[ , mautoservicio_adj           := ifelse( foto_mes == '202010' ,   mautoservicio*1.271,
                                           ifelse( foto_mes == '202011' ,   mautoservicio*1.239,
                                           ifelse( foto_mes == '202012' ,   mautoservicio*1.199,
                                           ifelse( foto_mes == '202101' ,   mautoservicio*1.158,
                                           ifelse( foto_mes == '202102' ,   mautoservicio*1.122,
                                           ifelse( foto_mes == '202103' ,   mautoservicio*1.074,
                                           ifelse( foto_mes == '202104' ,   mautoservicio*1.033,
                                           ifelse( foto_mes == '202105' ,   mautoservicio, mautoservicio))))))))]


dataset[ , mprestamos_personales_adj           := ifelse( foto_mes == '202010' ,   mprestamos_personales*1.271,
                                           ifelse( foto_mes == '202011' ,   mprestamos_personales*1.239,
                                           ifelse( foto_mes == '202012' ,   mprestamos_personales*1.199,
                                           ifelse( foto_mes == '202101' ,   mprestamos_personales*1.158,
                                           ifelse( foto_mes == '202102' ,   mprestamos_personales*1.122,
                                           ifelse( foto_mes == '202103' ,   mprestamos_personales*1.074,
                                           ifelse( foto_mes == '202104' ,   mprestamos_personales*1.033,
                                           ifelse( foto_mes == '202105' ,   mprestamos_personales, mprestamos_personales))))))))]


dataset[ , mrentabilidad_annual_adj           := ifelse( foto_mes == '202010' ,   mrentabilidad_annual*1.271,
                                           ifelse( foto_mes == '202011' ,   mrentabilidad_annual*1.239,
                                           ifelse( foto_mes == '202012' ,   mrentabilidad_annual*1.199,
                                           ifelse( foto_mes == '202101' ,   mrentabilidad_annual*1.158,
                                           ifelse( foto_mes == '202102' ,   mrentabilidad_annual*1.122,
                                           ifelse( foto_mes == '202103' ,   mrentabilidad_annual*1.074,
                                           ifelse( foto_mes == '202104' ,   mrentabilidad_annual*1.033,
                                           ifelse( foto_mes == '202105' ,   mrentabilidad_annual, mrentabilidad_annual))))))))]

dataset[ , mtarjeta_visa_consumo_adj           := ifelse( foto_mes == '202010' ,   mtarjeta_visa_consumo*1.271,
                                           ifelse( foto_mes == '202011' ,   mtarjeta_visa_consumo*1.239,
                                           ifelse( foto_mes == '202012' ,   mtarjeta_visa_consumo*1.199,
                                           ifelse( foto_mes == '202101' ,   mtarjeta_visa_consumo*1.158,
                                           ifelse( foto_mes == '202102' ,   mtarjeta_visa_consumo*1.122,
                                           ifelse( foto_mes == '202103' ,   mtarjeta_visa_consumo*1.074,
                                           ifelse( foto_mes == '202104' ,   mtarjeta_visa_consumo*1.033,
                                           ifelse( foto_mes == '202105' ,   mtarjeta_visa_consumo, mtarjeta_visa_consumo))))))))]


dataset[ , mcaja_ahorro_adj           := ifelse( foto_mes == '202010' ,   mcaja_ahorro*1.271,
                                           ifelse( foto_mes == '202011' ,   mcaja_ahorro*1.239,
                                           ifelse( foto_mes == '202012' ,   mcaja_ahorro*1.199,
                                           ifelse( foto_mes == '202101' ,   mcaja_ahorro*1.158,
                                           ifelse( foto_mes == '202102' ,   mcaja_ahorro*1.122,
                                           ifelse( foto_mes == '202103' ,   mcaja_ahorro*1.074,
                                           ifelse( foto_mes == '202104' ,   mcaja_ahorro*1.033,
                                           ifelse( foto_mes == '202105' ,   mcaja_ahorro, mcaja_ahorro))))))))]


dataset[ , mcomisiones_mantenimiento_adj           := ifelse( foto_mes == '202010' ,   mcomisiones_mantenimiento*1.271,
                                           ifelse( foto_mes == '202011' ,   mcomisiones_mantenimiento*1.239,
                                           ifelse( foto_mes == '202012' ,   mcomisiones_mantenimiento*1.199,
                                           ifelse( foto_mes == '202101' ,   mcomisiones_mantenimiento*1.158,
                                           ifelse( foto_mes == '202102' ,   mcomisiones_mantenimiento*1.122,
                                           ifelse( foto_mes == '202103' ,   mcomisiones_mantenimiento*1.074,
                                           ifelse( foto_mes == '202104' ,   mcomisiones_mantenimiento*1.033,
                                           ifelse( foto_mes == '202105' ,   mcomisiones_mantenimiento, mcomisiones_mantenimiento))))))))]

dataset[ , mcuenta_corriente_adj           := ifelse( foto_mes == '202010' ,   mcuenta_corriente*1.271,
                                           ifelse( foto_mes == '202011' ,   mcuenta_corriente*1.239,
                                           ifelse( foto_mes == '202012' ,   mcuenta_corriente*1.199,
                                           ifelse( foto_mes == '202101' ,   mcuenta_corriente*1.158,
                                           ifelse( foto_mes == '202102' ,   mcuenta_corriente*1.122,
                                           ifelse( foto_mes == '202103' ,   mcuenta_corriente*1.074,
                                           ifelse( foto_mes == '202104' ,   mcuenta_corriente*1.033,
                                           ifelse( foto_mes == '202105' ,   mcuenta_corriente, mcuenta_corriente))))))))]

dataset[ , mactivos_margen_adj           := ifelse( foto_mes == '202010' ,   mactivos_margen*1.271,
                                           ifelse( foto_mes == '202011' ,   mactivos_margen*1.239,
                                           ifelse( foto_mes == '202012' ,   mactivos_margen*1.199,
                                           ifelse( foto_mes == '202101' ,   mactivos_margen*1.158,
                                           ifelse( foto_mes == '202102' ,   mactivos_margen*1.122,
                                           ifelse( foto_mes == '202103' ,   mactivos_margen*1.074,
                                           ifelse( foto_mes == '202104' ,   mactivos_margen*1.033,
                                           ifelse( foto_mes == '202105' ,   mactivos_margen, mactivos_margen))))))))]

dataset[ , mrentabilidad_adj           := ifelse( foto_mes == '202010' ,   mrentabilidad*1.271,
                                           ifelse( foto_mes == '202011' ,   mrentabilidad*1.239,
                                           ifelse( foto_mes == '202012' ,   mrentabilidad*1.199,
                                           ifelse( foto_mes == '202101' ,   mrentabilidad*1.158,
                                           ifelse( foto_mes == '202102' ,   mrentabilidad*1.122,
                                           ifelse( foto_mes == '202103' ,   mrentabilidad*1.074,
                                           ifelse( foto_mes == '202104' ,   mrentabilidad*1.033,
                                           ifelse( foto_mes == '202105' ,   mrentabilidad, mrentabilidad))))))))]

dataset[ , Visa_msaldototal_adj           := ifelse( foto_mes == '202010' ,   Visa_msaldototal*1.271,
                                           ifelse( foto_mes == '202011' ,   Visa_msaldototal*1.239,
                                           ifelse( foto_mes == '202012' ,   Visa_msaldototal*1.199,
                                           ifelse( foto_mes == '202101' ,   Visa_msaldototal*1.158,
                                           ifelse( foto_mes == '202102' ,   Visa_msaldototal*1.122,
                                           ifelse( foto_mes == '202103' ,   Visa_msaldototal*1.074,
                                           ifelse( foto_mes == '202104' ,   Visa_msaldototal*1.033,
                                           ifelse( foto_mes == '202105' ,   Visa_msaldototal, Visa_msaldototal))))))))]

dataset[ , Visa_mpagospesos_adj           := ifelse( foto_mes == '202010' ,   Visa_mpagospesos*1.271,
                                           ifelse( foto_mes == '202011' ,   Visa_mpagospesos*1.239,
                                           ifelse( foto_mes == '202012' ,   Visa_mpagospesos*1.199,
                                           ifelse( foto_mes == '202101' ,   Visa_mpagospesos*1.158,
                                           ifelse( foto_mes == '202102' ,   Visa_mpagospesos*1.122,
                                           ifelse( foto_mes == '202103' ,   Visa_mpagospesos*1.074,
                                           ifelse( foto_mes == '202104' ,   Visa_mpagospesos*1.033,
                                           ifelse( foto_mes == '202105' ,   Visa_mpagospesos, Visa_mpagospesos))))))))]

dataset[ , mcomisiones_adj           := ifelse( foto_mes == '202010' ,   mcomisiones*1.271,
                                           ifelse( foto_mes == '202011' ,   mcomisiones*1.239,
                                           ifelse( foto_mes == '202012' ,   mcomisiones*1.199,
                                           ifelse( foto_mes == '202101' ,   mcomisiones*1.158,
                                           ifelse( foto_mes == '202102' ,   mcomisiones*1.122,
                                           ifelse( foto_mes == '202103' ,   mcomisiones*1.074,
                                           ifelse( foto_mes == '202104' ,   mcomisiones*1.033,
                                           ifelse( foto_mes == '202105' ,   mcomisiones, mcomisiones))))))))]

dataset[ , Visa_mconsumospesos_adj           := ifelse( foto_mes == '202010' ,   Visa_mconsumospesos*1.271,
                                           ifelse( foto_mes == '202011' ,   Visa_mconsumospesos*1.239,
                                           ifelse( foto_mes == '202012' ,   Visa_mconsumospesos*1.199,
                                           ifelse( foto_mes == '202101' ,   Visa_mconsumospesos*1.158,
                                           ifelse( foto_mes == '202102' ,   Visa_mconsumospesos*1.122,
                                           ifelse( foto_mes == '202103' ,   Visa_mconsumospesos*1.074,
                                           ifelse( foto_mes == '202104' ,   Visa_mconsumospesos*1.033,
                                           ifelse( foto_mes == '202105' ,   Visa_mconsumospesos, Visa_mconsumospesos))))))))]

dataset[ , Visa_mfinanciacion_limite_adj           := ifelse( foto_mes == '202010' ,   Visa_mfinanciacion_limite*1.271,
                                           ifelse( foto_mes == '202011' ,   Visa_mfinanciacion_limite*1.239,
                                           ifelse( foto_mes == '202012' ,   Visa_mfinanciacion_limite*1.199,
                                           ifelse( foto_mes == '202101' ,   Visa_mfinanciacion_limite*1.158,
                                           ifelse( foto_mes == '202102' ,   Visa_mfinanciacion_limite*1.122,
                                           ifelse( foto_mes == '202103' ,   Visa_mfinanciacion_limite*1.074,
                                           ifelse( foto_mes == '202104' ,   Visa_mfinanciacion_limite*1.033,
                                           ifelse( foto_mes == '202105' ,   Visa_mfinanciacion_limite, Visa_mfinanciacion_limite))))))))]

dataset[ , mtransferencias_recibidas_adj           := ifelse( foto_mes == '202010' ,   mtransferencias_recibidas*1.271,
                                           ifelse( foto_mes == '202011' ,   mtransferencias_recibidas*1.239,
                                           ifelse( foto_mes == '202012' ,   mtransferencias_recibidas*1.199,
                                           ifelse( foto_mes == '202101' ,   mtransferencias_recibidas*1.158,
                                           ifelse( foto_mes == '202102' ,   mtransferencias_recibidas*1.122,
                                           ifelse( foto_mes == '202103' ,   mtransferencias_recibidas*1.074,
                                           ifelse( foto_mes == '202104' ,   mtransferencias_recibidas*1.033,
                                           ifelse( foto_mes == '202105' ,   mtransferencias_recibidas, mtransferencias_recibidas))))))))]

dataset[ , Master_mfinanciacion_limite_adj           := ifelse( foto_mes == '202010' ,   Master_mfinanciacion_limite*1.271,
                                           ifelse( foto_mes == '202011' ,   Master_mfinanciacion_limite*1.239,
                                           ifelse( foto_mes == '202012' ,   Master_mfinanciacion_limite*1.199,
                                           ifelse( foto_mes == '202101' ,   Master_mfinanciacion_limite*1.158,
                                           ifelse( foto_mes == '202102' ,   Master_mfinanciacion_limite*1.122,
                                           ifelse( foto_mes == '202103' ,   Master_mfinanciacion_limite*1.074,
                                           ifelse( foto_mes == '202104' ,   Master_mfinanciacion_limite*1.033,
                                           ifelse( foto_mes == '202105' ,   Master_mfinanciacion_limite, Master_mfinanciacion_limite))))))))]

dataset[ , mcomisiones_otras_adj           := ifelse( foto_mes == '202010' ,   mcomisiones_otras*1.271,
                                           ifelse( foto_mes == '202011' ,   mcomisiones_otras*1.239,
                                           ifelse( foto_mes == '202012' ,   mcomisiones_otras*1.199,
                                           ifelse( foto_mes == '202101' ,   mcomisiones_otras*1.158,
                                           ifelse( foto_mes == '202102' ,   mcomisiones_otras*1.122,
                                           ifelse( foto_mes == '202103' ,   mcomisiones_otras*1.074,
                                           ifelse( foto_mes == '202104' ,   mcomisiones_otras*1.033,
                                           ifelse( foto_mes == '202105' ,   mcomisiones_otras, mcomisiones_otras))))))))]

dataset[ , mcaja_ahorro_dolares_adj           := ifelse( foto_mes == '202010' ,   mcaja_ahorro_dolares*1.271,
                                           ifelse( foto_mes == '202011' ,   mcaja_ahorro_dolares*1.239,
                                           ifelse( foto_mes == '202012' ,   mcaja_ahorro_dolares*1.199,
                                           ifelse( foto_mes == '202101' ,   mcaja_ahorro_dolares*1.158,
                                           ifelse( foto_mes == '202102' ,   mcaja_ahorro_dolares*1.122,
                                           ifelse( foto_mes == '202103' ,   mcaja_ahorro_dolares*1.074,
                                           ifelse( foto_mes == '202104' ,   mcaja_ahorro_dolares*1.033,
                                           ifelse( foto_mes == '202105' ,   mcaja_ahorro_dolares, mcaja_ahorro_dolares))))))))]

dataset[ , mttarjeta_visa_debitos_automaticos_adj           := ifelse( foto_mes == '202010' ,   mttarjeta_visa_debitos_automaticos*1.271,
                                           ifelse( foto_mes == '202011' ,   mttarjeta_visa_debitos_automaticos*1.239,
                                           ifelse( foto_mes == '202012' ,   mttarjeta_visa_debitos_automaticos*1.199,
                                           ifelse( foto_mes == '202101' ,   mttarjeta_visa_debitos_automaticos*1.158,
                                           ifelse( foto_mes == '202102' ,   mttarjeta_visa_debitos_automaticos*1.122,
                                           ifelse( foto_mes == '202103' ,   mttarjeta_visa_debitos_automaticos*1.074,
                                           ifelse( foto_mes == '202104' ,   mttarjeta_visa_debitos_automaticos*1.033,
                                           ifelse( foto_mes == '202105' ,   mttarjeta_visa_debitos_automaticos, mttarjeta_visa_debitos_automaticos))))))))]

dataset[ , mtransferencias_emitidas_adj           := ifelse( foto_mes == '202010' ,   mtransferencias_emitidas*1.271,
                                           ifelse( foto_mes == '202011' ,   mtransferencias_emitidas*1.239,
                                           ifelse( foto_mes == '202012' ,   mtransferencias_emitidas*1.199,
                                           ifelse( foto_mes == '202101' ,   mtransferencias_emitidas*1.158,
                                           ifelse( foto_mes == '202102' ,   mtransferencias_emitidas*1.122,
                                           ifelse( foto_mes == '202103' ,   mtransferencias_emitidas*1.074,
                                           ifelse( foto_mes == '202104' ,   mtransferencias_emitidas*1.033,
                                           ifelse( foto_mes == '202105' ,   mtransferencias_emitidas, mtransferencias_emitidas))))))))]

dataset[ , Visa_msaldopesos_adj           := ifelse( foto_mes == '202010' ,   Visa_msaldopesos*1.271,
                                           ifelse( foto_mes == '202011' ,   Visa_msaldopesos*1.239,
                                           ifelse( foto_mes == '202012' ,   Visa_msaldopesos*1.199,
                                           ifelse( foto_mes == '202101' ,   Visa_msaldopesos*1.158,
                                           ifelse( foto_mes == '202102' ,   Visa_msaldopesos*1.122,
                                           ifelse( foto_mes == '202103' ,   Visa_msaldopesos*1.074,
                                           ifelse( foto_mes == '202104' ,   Visa_msaldopesos*1.033,
                                           ifelse( foto_mes == '202105' ,   Visa_msaldopesos, Visa_msaldopesos))))))))]

dataset[ , mcuenta_debitos_automaticos_adj           := ifelse( foto_mes == '202010' ,   mcuenta_debitos_automaticos*1.271,
                                           ifelse( foto_mes == '202011' ,   mcuenta_debitos_automaticos*1.239,
                                           ifelse( foto_mes == '202012' ,   mcuenta_debitos_automaticos*1.199,
                                           ifelse( foto_mes == '202101' ,   mcuenta_debitos_automaticos*1.158,
                                           ifelse( foto_mes == '202102' ,   mcuenta_debitos_automaticos*1.122,
                                           ifelse( foto_mes == '202103' ,   mcuenta_debitos_automaticos*1.074,
                                           ifelse( foto_mes == '202104' ,   mcuenta_debitos_automaticos*1.033,
                                           ifelse( foto_mes == '202105' ,   mcuenta_debitos_automaticos, mcuenta_debitos_automaticos))))))))]

dataset[ , mtarjeta_master_consumo_adj           := ifelse( foto_mes == '202010' ,   mtarjeta_master_consumo*1.271,
                                           ifelse( foto_mes == '202011' ,   mtarjeta_master_consumo*1.239,
                                           ifelse( foto_mes == '202012' ,   mtarjeta_master_consumo*1.199,
                                           ifelse( foto_mes == '202101' ,   mtarjeta_master_consumo*1.158,
                                           ifelse( foto_mes == '202102' ,   mtarjeta_master_consumo*1.122,
                                           ifelse( foto_mes == '202103' ,   mtarjeta_master_consumo*1.074,
                                           ifelse( foto_mes == '202104' ,   mtarjeta_master_consumo*1.033,
                                           ifelse( foto_mes == '202105' ,   mtarjeta_master_consumo, mtarjeta_master_consumo))))))))]

    
  columnas_extendidas <-  copy( setdiff(  colnames(dataset), columnas_originales ) )
  
   #delete original attributes without inflation adjustment
  dataset[, c('mpasivos_margen','mpayroll','mcuentas_saldo','mautoservicio','mprestamos_personales','mrentabilidad_annual','mtarjeta_visa_consumo','mcaja_ahorro',
              'mcomisiones_mantenimiento','mcuenta_corriente','mactivos_margen','mrentabilidad','Visa_msaldototal','Visa_mpagospesos','mcomisiones','Visa_mconsumospesos',
              'Visa_mfinanciacion_limite','mtransferencias_recibidas','Master_mfinanciacion_limite','mcomisiones_otras','mcaja_ahorro_dolares','mttarjeta_visa_debitos_automaticos',
              'mtransferencias_emitidas','Visa_msaldopesos','mcuenta_debitos_automaticos','mtarjeta_master_consumo'):=NULL]
 
  #grabo con nombre extendido
  fwrite( dataset,
          file=arch_destino,
          sep= "," )
}
#------------------------------------------------------------------------------

#kcarpeta_datasets    <- "../input/laboratorio-de-implementacion-i-2021/"   #KAGGLE
kcarpeta_datasets    <- "./buckets/b1/datasets/"                          #VM o Ubuntu

#Archivo con datos etiquetados para entrenamiento
karchivo_entrada      <-  paste0(kcarpeta_datasets, "competencia2_2022.csv.gz")
karchivo_salida      <-  paste0(kcarpeta_datasets, "competencia2_2022_ADJ.csv.gz")

#lectura rapida del dataset  usando fread  de la libreria  data.table
dataset1  <- fread(karchivo_entrada)

EnriquecerDataset( dataset1, karchivo_salida )

quit( save="no")
# Out:
#        used    (Mb) gc trigger (Mb)   max used   (Mb)
# Ncells  757711 40.5   1349487    72.1    1349487   72.1
# Vcells 1582415 12.1 805806000  6147.9 1007257499 7684.8
